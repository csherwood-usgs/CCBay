# %% [markdown]
# ## Constructing grids for COAWST / SWAN for Cape Cod Bay and Sandwich
#
# `CCBay_grid_v5`
#
# This is a duplicate of the code in `_v3` and `v4` but uses bathymetry from the USGS jetyak survey of June 6, 2016 and the UAS topography from Sept 21, 2016. The resulting grids are named FG5, MG5, and CG5.
#
# #### Data
# * 10-gridded topo/bathy for entire CCBay from Brian Andrews synthesis `CCBay_10m.tif`
# * 5-m gridded 2013 topo/bathy from USACE lidar in from Plymouth to Sandy Neck `5-m_grid_from_lidar.tif`
# * USGS jetyak gridded bathy `2016-030-FA_bathymetry_4m.tif`
# * 0.1-m gridded UAS structure-from-motion topography for Sandwich Town Neck Beach `2016-09-21_SandwichTNB_DEM_10cm_trimmed.tif`
# * Crappy coastline for visual reference based on 0-m contour extracted from 10-m grid `shoreline.txt`
#
# #### Grids
# Three grids (fine, medium, and coarse) are developed in this notebook: FG4, MG4, and CG4. The data and original grid coordinates are all in NAD83(2011) UTM Zone 19N (meters) and NADV88 (m). The lat/lon coordinates exported for COAWST are in WGS84.
#
# #### Process
# * Define some of the functions used later.
# * Load the shoreline data.
# * Make the grid coordinates, based on origin, rotation, and spacing. This produces meshes Xf,Yf; Xm,Ym; and Xc, Yc.
# * Import the topo/bathy data as arrays from `.tif` tiles.
# * Smooth and fill gaps in 10-m data.
# * Smooth lidar data and remove outer 4 cells.
# * Smooth and decimate the SfM data.
# * Make fine grid
#     * Interpolate SfM data onto fine grid
#     * Interpolate lidar data onto fine grid
#     * Cut hole in lidar version of fine grid where SfM data exists
#     * Build complete fine grid by combining SfM and lidar versions
#     * Apply a linear blend across the junction of the two data sets, extending 5 cells each way
# * Make medium grid
#     * Interpolate fine grid data onto medium grid
#     * Interpolate lidar data onto medium grid
#     * Interpolate 10-m data onto medium grid
#     * Cut hole in 10-m version of medium grid where lidar data exists
#     * Cut hole in lidar version of medium grid where fine grid data exists
#     * Build complete grid by combining fine, lidar, and 10-m versions of medium grid
# * Make coarse grid
#     * Interpolate medium grid data onto coarse grid
#     * Interpolate 10-m data onto coarse grid
#     * Cut hole in 10-m version of coarse grid where medium grid data exists
#     * Build complete grid by combining medium and 10-m versions of coarse grid
# * Calculate the lat/lon coordinates for the grids.
# * Export the grids as `.mat` files.

# %%
import numpy as np
import pandas as pd
import scipy.io

from IPython.display import display, HTML
import matplotlib.pyplot as plt
from scipy import interpolate
from astropy.convolution import Gaussian2DKernel
from astropy.convolution import convolve
from scipy.signal import convolve as scipy_convolve

import xarray as xr
# %matplotlib inline

# %%
# some functions used here
def pcoord(x, y):
    """
    Convert x, y to polar coordinates r, az (geographic convention)
    r,az = pcoord(x, y)
    """
    r  = np.sqrt( x**2 + y**2 )
    az = np.degrees( np.arctan2(x, y) )
    # az[where(az<0.)[0]] += 360.
    az = (az+360.)%360.
    return r, az

def xycoord(r, az):
    """
    Convert r, az [degrees, geographic convention] to rectangular coordinates
    x,y = xycoord(r, az)
    """
    x = r * np.sin(np.radians(az))
    y = r * np.cos(np.radians(az))
    return x, y

def buildGrid(xp,yp,alp,dx,dy,mxc,myc):
    '''
    X, Y = buildGrid(xp,yp,alp,dx,dy,mxc,myc) builds a rectangular grid
    
    Input :
        xp: x grid origin
        yp: y grid origin
        alp: degrees rotation of x-axis
        dx: x-direction grid spacing
        dy: y-direction grid spacing
        mxc: number of meshes in x-direction
        myc: number of meshes in y-direction
        
    Based on the Matlab function of Dave Thompson
    '''
    xlen = (mxc-1)*dx
    ylen = (myc-1)*dy
    
    x = np.arange(xp,xp+xlen+dx,dx)
    y = np.arange(yp,yp+ylen+dy,dy)

    X,Y = np.meshgrid(x,y);
    X = X-xp
    Y = Y-yp

    if alp != 0.:
       r,az = pcoord(X,Y)
       X,Y = xycoord(r,az+alp)
        
    X = X+xp
    Y = Y+yp
    print("Shape of X and Y: ",np.shape(X),np.shape(Y))

    return X, Y

# %%
# data directory
ddir = r"D:/crs/proj/2015_Sandwich/CCBay_Modeling/grid_data/"

# %%
# load the coarse shoreline
s = np.genfromtxt(ddir+'shoreline.txt', delimiter=',')

# %%
# spacing for the three grids
dxyf = 5.
dxym = 35.
dxyc = 245.
# angle of north end
alp = 130.

# make the coarse box
# direction to origin of coarse grid...same angle for base line, even
# increment of dxc
# back calculate location of lower left corner from upper left corner
LMc = 192.
MMc = 68.
xul = 366490.
yul = 4652500.
dxo,dyo = xycoord( (MMc-1)*dxyc, alp+90)
xpc = xul+dxo
ypc = yul+dyo

xlenc = (LMc-1)*dxyc
ylenc = (MMc-1)*dxyc

# box corners
bc = np.empty((4,2),float)
bc[0,:]=[xpc,ypc]
dxb, dyb = xycoord( xlenc, alp );
bc[1,:] = bc[0,:]+[dxb, dyb];
dxb, dyb = xycoord( ylenc, alp-90);
bc[2,:] = bc[1,:]+[dxb, dyb];
dxb, dyb = xycoord( xlenc, alp+180);
bc[3,:] = bc[2,:]+[dxb, dyb]

# make the coarse grid
dxc = dxyc;
dyc = dxyc;
print('Coarse grid is {} x {}, total = {}'.format(LMc,MMc,LMc*MMc))
Xc,Yc = buildGrid( 0., 0., alp-90., dxc, dyc, LMc, MMc );
Xc = Xc + xpc
Yc = Yc + ypc

# box corners should be the same as the corner points in X and Y
print(bc)

print(Xc[0,0],Yc[0,0])
print(Xc[-1,0],Yc[-1,0])
# Out:
# Coarse grid is 192.0 x 68.0, total = 13056.0
# Shape of X and Y:  (68, 192) (68, 192)
# [[ 355938.641387   4639925.3804662 ]
#  [ 391785.69110275 4609846.13427092]
#  [ 402337.04971575 4622420.75380472]
#  [ 366490.         4652500.        ]]
# 355938.64138699544 4639925.380466202
# 366490.0 4652500.0

# %%
# medium grid box
dxm = dxym
dym = dxym
LMm = 190
MMm = 64
# check to make sure it is divisible by dxc and dyc
print("These numbers should be integers:")
print((LMm-1)*dxm/dxc)
print((MMm-1)*dym/dyc)
# indices in coarse grid for origin of medium grid (found by hand)
row = 7
col = 88
# corresponding coordinates
xpm = Xc[row,col];
ypm = Yc[row,col];
print("Origin of medium grid")
print(xpm,ypm)
print('Medium grid is {} x {}, total = {}'.format(LMm,MMm,LMm*MMm))
Xm,Ym = buildGrid( 0., 0., alp-90., dxm, dym, LMm, MMm );
Xm = Xm + xpm
Ym = Ym + ypm
xlenm = (LMm-1)*dxm; # should be even increment of coarse grid dxc
ylenm = (MMm-1)*dym; # should be even increment of coarse grid dyc
# Out:
# These numbers should be integers:
# 27.0
# 9.0
# Origin of medium grid
# 373556.940331253 4627380.64582131
# Medium grid is 190 x 64, total = 12160
# Shape of X and Y:  (64, 190) (64, 190)

# %%
# plot to check that origin == correct coarse grid location
plt.plot(s[:,0],s[:,1],'.k')
plt.plot(Xc,Yc,'.r');
plt.plot(xpm,ypm,'xm');
plt.xlim((3.73e5,3.74e5))
plt.ylim((4.627e6,4.628e6))
# Out:
# (4627000.0, 4628000.0)

# %%
# medium grid box
dxf = dxyf
dyf = dxyf
LMf = 288
MMf = 126
# check to make sure it is divisible by dxc and dyc
print("These numbers should be integers:")
print((LMf-1)*dxf/dxm)
print((MMf-1)*dyf/dym)
# indices in coarse grid for origin of medium grid (found by hand)
row = 3
col = 95
# corresponding coordinates
xpf = Xm[row,col];
ypf = Ym[row,col];
print("Origin of fine grid")
print(xpf,ypf)
print('Fine grid is {} x {}, total = {}'.format(LMf,MMf,LMf*MMf))
Xf,Yf = buildGrid( 0., 0., alp-90., dxf, dyf, LMf, MMf );
Xf = Xf + xpf
Yf = Yf + ypf
# Out:
# These numbers should be integers:
# 41.0
# 17.857142857142858
# Origin of fine grid
# 376171.53080364066 4625323.811685629
# Fine grid is 288 x 126, total = 36288
# Shape of X and Y:  (126, 288) (126, 288)

# %%
# plot to check that origin == correct coarse grid location
plt.plot(s[:,0],s[:,1],'.k')
plt.plot(Xm,Ym,'.y');
plt.plot(xpf,ypf,'xb');
plt.xlim((3.760e5,3.78e5))
plt.ylim((4.624e6,4.626e6))
# Out:
# (4624000.0, 4626000.0)

# %%
plt.plot(s[:,0],s[:,1],'.k')
plt.plot(bc[:,0],bc[:,1],'or')
plt.plot(bc[:,0],bc[:,1],'-r')
plt.plot([bc[0,0], bc[3,0]],[bc[0,1], bc[3,1]],'-r')
plt.plot(Xc,Yc,'.r')
plt.plot(Xm,Ym,'.y')
plt.plot(Xf,Yf,'.b')
plt.axis('equal');

# %%
plt.plot(s[:,0],s[:,1],'.k')
plt.plot(Xc,Yc,'.r')
plt.plot(Xm,Ym,'.y')
plt.plot(Xf,Yf,'.b')
plt.xlim((3.72e5,3.82e5))
plt.ylim((4.622e6,4.63e6));

# %%
plt.plot(s[:,0],s[:,1],'.k')
plt.plot(Xc,Yc,'.r')
plt.plot(Xm,Ym,'.y')
plt.plot(Xf,Yf,'.b')
plt.xlim((3.76e5,3.775e5))
plt.ylim((4.624e6,4.626e6))
# Out:
# (4624000.0, 4626000.0)

# %% [markdown]
# #### Import the bathymetry data in gridded `.tif` files

# %%
# %%time
# Instead of importing as points, import from the tiffs, which allows grid smoothing
'''
# These were exported from Global Mapper from the grids as xyz files
p10 = np.genfromtxt(ddir+'CCBay10m_south_points.txt', delimiter=',')
plidar = np.genfromtxt(ddir+'2013_lidar_points.txt', delimiter=',')
psfm = np.genfromtxt(ddir+'2016-03-30_SandwichTNB_points.txt', delimiter=',')
'''
# This grid was generated by Brian Andrews in ArcGIS
# open the tif with XArray as a DataArray
fn = ddir+'CCBay_10m.tif'
da = xr.open_rasterio(fn)

# Not sure how da.values got a singleton dimension, but squeeze gets rid of it.
print( np.shape(np.flipud(da['y'].values)), np.shape(da['x'].values), np.shape( np.flipud(da.values)) )

# However, make sure to squeeze before flipping
z10 = np.flipud(np.squeeze(da.values))

# Missing values are -3.40282347e+38. Replace with NaNs as follows:
z10[z10 <= -3.4e+38]=np.NaN

x10 = da['x'].values
y10 = np.flipud(da['y'].values)
# Out:
# (4952,) (8215,) (1, 4952, 8215)
# Wall time: 2.5 s

# %%
plt.pcolormesh(x10,y10,z10,vmin=-30,vmax=10)
plt.title('10-m CCBay gridded topo/bathy data')
plt.colorbar();

# %%
# clip only the data we need to make interpolations go faster
ix = int(np.argwhere(x10<=404000.)[-1])
iy = int(np.argwhere(y10<=4654000.)[-1])
print(np.shape(z10))
z10c = z10[0:iy,0:ix]
x10c=x10[:ix]
y10c=y10[:iy]
print(np.shape(z10c),np.shape(x10c),np.shape(y10c))
plt.pcolormesh(x10c,y10c,z10c,vmin=-30,vmax=10)
plt.title('10-m CCBay gridded topo/bathy data, clipped')
plt.colorbar();
# Out:
# (4952, 8215)
# (3852, 4874) (4874,) (3852,)

# %% [markdown]
# ### Get rid of the NaNs in the 10-m data
# * Smooth with Astropy Gaussian convolution, which replaces NaNs w/ interpolated values
# * Make a second grid by smoothing again
# * Fill NaNs in the first grid with values from the twice-smoothed grid. This fills some holes in Barnstble Harbor
# * Fill remainder of NaNs with fixed value

# %%
# %%time
# Smooth with gaussian 
kernel = Gaussian2DKernel(x_stddev=2)
# Astropy's convolution replaces the NaN pixels with a kernel-weighted
# interpolation from their neighbors. The 'extend' option prevents issues at edges with NaNs.
z10cs = convolve(z10c, kernel, boundary='extend')

# There are still some NaNs in this...smooth again, but only use these data to fill NaNs
z10css = convolve(z10cs, kernel, boundary='extend')
# Out:
# WARNING: nan_treatment='interpolate', however, NaN values detected post convolution. A contiguous region of NaN values, larger than the kernel size, are present in the input array. Increase the kernel size to avoid this. [astropy.convolution.convolve]
# Wall time: 39.7 s

# %%
# Replace some of the NaNs with values from the twice-smoothed array.
# This fills in the holes in Barnstable Harbor with semi-reasonable depths.
z10csf = z10cs.copy()
z10csf[np.isnan(z10cs)]=z10css[np.isnan(z10cs)]
# Now set remaining NaNs to a fixed value
z10csf[np.isnan(z10csf)]=20.

plt.pcolormesh(x10c,y10c,z10csf,vmin=-50,vmax=15)
plt.title('10-m CCBay gridded topo/bathy data, clipped+smoothed')
plt.colorbar();

# %% [markdown]
# ### Import the lidar data and smooth

# %%
# This grid was generated by CRS GlobalMapper from USACE lidar data
# open the tif with XArray as a DataArray
fn = ddir+'5-m_grid_from_lidar.tif'
da = xr.open_rasterio(fn)

# Not sure how da.values got a singleton dimension, but squeeze gets rid of it.
print( np.shape(np.flipud(da['y'].values)), np.shape(da['x'].values), np.shape( np.flipud(da.values)) )

# However, make sure to squeeze before flipping
zlidar = np.flipud(np.squeeze(da.values))

# Missing values are -32767. Can replace with NaNs as follows:
zlidar[zlidar<-32766]=np.NaN
xlidar = da['x'].values
ylidar = np.flipud(da['y'].values)
# Out:
# (1673,) (2450,) (1, 1673, 2450)

# %%
# Smooth the lidar data with the scipy convolution. This will remove data around the edges.
kernel = Gaussian2DKernel(x_stddev=.5)
print("kernel size: ", kernel.shape)
# Convolution: scipy's direct convolution mode spreads out NaNs
zlidars = scipy_convolve(zlidar, kernel, mode='same', method='direct')
# Out:
# kernel size:  (5, 5)

# %%
fig = plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.pcolormesh(xlidar,ylidar,zlidar,vmin=-10,vmax=10)
plt.title('5-m lidar gridded topo/bathy data')
plt.colorbar();
plt.subplot(1,2,2)
plt.pcolormesh(xlidar,ylidar,zlidars,vmin=-10,vmax=10)
plt.title('5-m lidar gridded topo/bathy data, smoothed')
plt.colorbar();

# %% [markdown]
# ### Import the Jetyak data

# %%
fn=ddir+'2016-030-FA_bathymetry_4m.tif'
da = xr.open_rasterio(fn)
da.values
# Out:
# array([[[-32767., -32767., -32767., ..., -32767., -32767., -32767.],
#         [-32767., -32767., -32767., ..., -32767., -32767., -32767.],
#         [-32767., -32767., -32767., ..., -32767., -32767., -32767.],
#         ...,
#         [-32767., -32767., -32767., ..., -32767., -32767., -32767.],
#         [-32767., -32767., -32767., ..., -32767., -32767., -32767.],
#         [-32767., -32767., -32767., ..., -32767., -32767., -32767.]]],
#       dtype=float32)

# %%
# Not sure how da.values got a singleton dimension, but squeeze gets rid of it.
print( np.shape(np.flipud(da['y'].values)), np.shape(da['x'].values), np.shape( np.flipud(da.values)) )

# However, make sure to squeeze before flipping
zjet = np.flipud(np.squeeze(da.values))

# Missing values are -32767. Can replace with NaNs as follows:
zjet[zjet<-32766]=np.NaN

xjet = da['x'].values
yjet = np.flipud(da['y'].values)

plt.pcolormesh(xjet,yjet,zjet,vmin=-10,vmax=10)
plt.title('0.1-m gridded SfM topo data')
plt.colorbar();
# Out:
# (331,) (331,) (1, 331, 331)

# %% [markdown]
# ### It looks like some smoothing/interpolation edge effects occur on the shallow end of the jetyak data, so NaN out values above -1 m.

# %%
zjet[zjet>=-1.]=np.NaN
# Out:
# C:\Users\csherwood\AppData\Local\Continuum\miniconda3\envs\IOOS\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in greater_equal
#   """Entry point for launching an IPython kernel.

# %%
# are there any NaNs inside the grid?
zjet_n = zjet.copy()
zjet_n[np.isnan(zjet_n)]=100.
fig = plt.figure(figsize=(12,6))
plt.pcolormesh(xjet,yjet,zjet_n,vmin=-10,vmax=10)
plt.title('Looking for NaNs')
plt.colorbar();
# no...so we should convolve with scipy convolve, which will expand the region of NaNs

# %% [raw]
# # dont need this smoothed yet
#
# # We smooth with a Gaussian kernel
# # size of the kernal depends on std. dev.: .5 = 4x4,  1 = 9x9, 1.5 = 13x13
# kj = Gaussian2DKernel(x_stddev=1.)
# print(np.shape(kj))
#
# # alternative box-car kernal
# kj = np.ones((5,5)) / (5*5)
#
# # astropy's convolution replaces the NaN pixels with a kernel-weighted
# # interpolation from their neighbors
# # zjet_s = convolve(zjet, kj)
#
# # scipy's convolution includes NaNs in calc. So: convolve, using method='direct'
# # (default might use fft, which will NaN everything)
# # this converts edge values to NaNs
# zjet_min = np.nanmin(zjet)
# print(zjet_min)
#
# zjet_s = zjet.copy()
# zjet_s = scipy_convolve(zjet_s, kj, mode='same', method='direct')
# zjet_newmin = np.nanmin(zjet_s)
#
# print("Unsmoothed min:",zjet_min,'Smoothed min:',zjet_newmin)
#
# fig = plt.figure(figsize=(12,6))
# plt.subplot(1,2,1)
# plt.pcolormesh(xjet,yjet,zjet,vmin=-10,vmax=0)
# plt.title('Jetyak bathy data')
# plt.colorbar();
# plt.subplot(1,2,2)
# plt.pcolormesh(xjet,yjet,zjet_s,vmin=-10,vmax=0)
# plt.title('Smoothed Jetyak bathy data')
# plt.colorbar();

# %% [markdown]
# ### Import the SfM data

# %%
# This grid was generated by CRS in Photoscan
# open the tif with XArray as a DataArray
fn = ddir+'2016-09-21_SandwichTNB_DEM_10cm_trimmed.tif'
da = xr.open_rasterio(fn)

# Not sure how da.values got a singleton dimension, but squeeze gets rid of it.
print( np.shape(np.flipud(da['y'].values)), np.shape(da['x'].values), np.shape( np.flipud(da.values)) )

# However, make sure to squeeze before flipping
zsfm = np.flipud(np.squeeze(da.values))

# Missing values are -32767. Can replace with NaNs as follows:
zsfm[zsfm<-32766]=np.NaN

xsfm = da['x'].values
ysfm = np.flipud(da['y'].values)

plt.pcolormesh(xsfm,ysfm,zsfm,vmin=-2,vmax=10)
plt.title('0.1-m gridded SfM topo data')
plt.colorbar();
# Out:
# (12379,) (12221,) (1, 12379, 12221)

# %% [markdown]
# ### Check the SfM data for internal NaNs
#
# * Convolve with a pretty big kernal to expand the NaN-holes and plot
# * This is really slow, because we have to use the direct method.
# * So slow, in fact, that I am skipping it for now

# %% [raw]
# %%time
# kn = np.ones((100,100))
# zsfm_nanchk = zsfm.copy()
# zsfm_nanchk = scipy_convolve(zsfm_nanchk, kn, mode='same', method='direct')
# plt.pcolormesh(xsfm,ysfm,zsfm_nanchk,vmin=-2,vmax=10)
# plt.title('0.1-m SfM grid convolved with 100 x 100 kernal')
# plt.colorbar();

# %% [markdown]
# ### Smooth the SfM data
# Use the Astropy library because it will replace NaNs with values interpolated by the smoothing kernel.
#
# http://docs.astropy.org/en/stable/index.html

# %%
# We smooth with a Gaussian kernel with x_stddev=1 (and y_stddev=1)
# It is a 9x9 array
kernel = Gaussian2DKernel(x_stddev=1)
# astropy's convolution replaces the NaN pixels with a kernel-weighted
# interpolation from their neighbors
zsfm_s = convolve(zsfm, kernel)

# %% [markdown]
# ### Decimate the SfM data from 10 cm to 50 cm: -> `zsfm_sd`

# %%
# Decimate the sfm data
zsfm_sd = zsfm_s[::5,::5]
xsfm_d = xsfm[::5]
ysfm_d = ysfm[::5]
print(np.shape(zsfm_s),np.shape(zsfm_sd),np.shape(xsfm_d),np.shape(ysfm_d))
plt.pcolormesh(xsfm_d,ysfm_d,zsfm_sd,vmin=-2,vmax=10)
plt.colorbar();
# Out:
# (12379, 12221) (2476, 2445) (2445,) (2476,)

# %% [markdown]
# ### Interpolate the SfM data onto the fine grid: ->`Zf1`...with lots of NaNs.

# %%
# %%time
# Make the fine grid with the SfM data
xp, yp = np.meshgrid(xsfm_d,ysfm_d)
xpyp = np.array((np.ravel(xp),np.ravel(yp))).T
zp = np.ravel(zsfm_sd)
print('xp ',np.shape(xp),'yp: ' ,np.shape(yp),'xpyp: ',np.shape(xpyp),'zp: :',np.shape(zp))
print('Xf ',np.shape(Xf),'Yf: ' ,np.shape(Yf),'grid points: ',np.shape(np.array((np.ravel(Xf), np.ravel(Yf))).T))

# interpolate data on to fine grid
Zf1 = interpolate.griddata( xpyp, zp, np.array((np.ravel(Xf), np.ravel(Yf))).T, method='linear', fill_value=np.NaN, rescale=False)
Zf1 = np.reshape(Zf1,np.shape(Xf))
# Out:
# xp  (2476, 2445) yp:  (2476, 2445) xpyp:  (6053820, 2) zp: : (6053820,)
# Xf  (126, 288) Yf:  (126, 288) grid points:  (36288, 2)
# Wall time: 20.8 s

# %%
fig = plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.pcolormesh(Xf,Yf,Zf1,vmin=-8,vmax=10,cmap=plt.cm.terrain)
for i in np.array([50,75,100,125,150,200,250]):
    plt.plot(Xf[:,i],Yf[:,i],'-')
plt.title('Zf1 - SfM data on fine grid')
plt.colorbar()
plt.axis('equal');
plt.subplot(1,2,2)
for i in np.array([50,75,100,125,150,200,250]):
    plt.plot(Xf[:,i],Zf1[:,i],'-')
plt.title('Profiles')
# Out:
# Text(0.5, 1.0, 'Profiles')

# %% [markdown]
# ### Interpolate the jetyak data onto the fine grid: -> Zf2...lots of holes

# %%
# %%time
# Make the fine grid with jetyak data
xp, yp = np.meshgrid(xjet,yjet)
xpyp = np.array((np.ravel(xp),np.ravel(yp))).T
# zp = np.ravel(zjet_s) # don't use the smoothed data...loose too much at edges
zp = np.ravel(zjet)
print('xp ',np.shape(xp),'yp: ' ,np.shape(yp),'xpyp: ',np.shape(xpyp),'zp: :',np.shape(zp))
print('Xf ',np.shape(Xf),'Yf: ' ,np.shape(Yf),'grid points: ',np.shape(np.array((np.ravel(Xf), np.ravel(Yf))).T))

# interpolate data on to fine grid
Zf2j = interpolate.griddata( xpyp, zp, np.array((np.ravel(Xf), np.ravel(Yf))).T, method='linear', fill_value=np.NaN, rescale=False)
Zf2j = np.reshape(Zf2j,np.shape(Xf))
# Out:
# xp  (331, 331) yp:  (331, 331) xpyp:  (109561, 2) zp: : (109561,)
# Xf  (126, 288) Yf:  (126, 288) grid points:  (36288, 2)
# Wall time: 1.98 s

# %%
plt.pcolormesh(Xf,Yf,Zf2j,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Zf2j - Jetyak data on fine grid')
plt.colorbar();

# %% [markdown]
# ### One way to combine the SfM and Jetyak fine grids is by averaging
# I am concerned this will make a step function where the second set of data starts

# %%
Zf2 = np.nanmean(np.stack( (Zf1,Zf2j), axis=-1), axis=2 )

# then smooth it in an attempt to fill the holes
# We smooth with a Gaussian kernel with x_stddev=1 (and y_stddev=1)
# It is a 9x9 array
kernel = Gaussian2DKernel(x_stddev=.5)
# astropy's convolution replaces the NaN pixels with a kernel-weighted
# interpolation from their neighbors

# nk=3
# kernal = np.ones((nk,nk))/(nk*nk)

print('Smoothing with kernel size',np.shape(kernel))
Zf2_s = convolve(Zf2, kernel, boundary='extend')

fig = plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.pcolormesh(Xf,Yf,Zf2,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Zf2 - SfM and Jetyak data on fine grid')
plt.colorbar();
plt.subplot(1,2,2)
plt.pcolormesh(Xf,Yf,Zf2_s,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Zf2_s - Smoothed SfM and Jetyak data on fine grid')
plt.colorbar();
# Out:
# C:\Users\csherwood\AppData\Local\Continuum\miniconda3\envs\IOOS\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: Mean of empty slice
#   """Entry point for launching an IPython kernel.
# Smoothing with kernel size (5, 5)

# %%
fig = plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.pcolormesh(Xf,Yf,Zf2,vmin=-8,vmax=10,cmap=plt.cm.terrain)
for i in np.array([50,75,100,125,150,200,250]):
    plt.plot(Xf[:,i],Yf[:,i],'-')
plt.title('Zf2 - SfM and Jetyak data on fine grid')
plt.colorbar()
plt.axis('equal');
plt.subplot(1,2,2)
for i in np.array([50,75,100,125,150,200,250]):
    plt.plot(Xf[:,i],Zf1[:,i],'-')
plt.title('Profiles')
# Out:
# Text(0.5, 1.0, 'Profiles')

# %% [markdown]
# ### Alternatively, try to feather the edges of the two grids together

# %% [markdown]
# #### Here are the existing grids

# %%
fig = plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.pcolormesh(Zf1,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('SfM topo')
plt.subplot(1,2,2)
plt.pcolormesh(Zf2j,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Jetyak bathy')
# Out:
# Text(0.5, 1.0, 'Jetyak bathy')

# %%
# test the weighting scheme
n=5
a=np.linspace(1.-1./n, 1./(n), n)
print(a)
# Out:
# [0.8  0.65 0.5  0.35 0.2 ]

# %%
# Find the indices for overlapping transects, then apply taper for overlapping points
wghts = np.ones_like(Zf1)
wghts[np.isnan(Zf1)]=np.nan

npoints, ntransects= np.shape(Zf1)
print('ntransects, npoints: ',ntransects,npoints)
for i in range(ntransects):
    j=np.argwhere(~np.isnan(Zf1[:,i]))
    k=np.argwhere(~np.isnan(Zf2j[:,i]))
    if(j.any() and k.any()):
        jend = int(j[-1])
        kstr = int(k[0])
        wghts[0:kstr-1,i]=1.
        ww = wghts[jend:npoints,i]
        ww[np.isnan(ww)]=0. # this will leave non-NaN values with weights of 1
        wghts[jend:npoints,i]=ww
        n=(jend-kstr)+1
        if(n==1):
            wghts[kstr,i]=.5
        if(n==2):
            wghts[kstr:jend+1,i]=np.array((2./3, 1./3))
        if(n>2):
            wghts[kstr:jend+1,i]=np.linspace(1.-1./n, 1./(n), n)
        print(i,n,wghts[kstr-2:jend+1,i])
    elif(j.any() and ~k.any()):
        jend = int(j[-1])
        wghts[0:jend,i]=1.
        wghts[jend+1:npoints,i]=0.
    elif(~j.any() and k.any()):
        kstr = int(k[0])
        wghts[0:kstr-1,i]=1.
        wghts[kstr:npoints,i]=0.
    else:
        wghts[:,i]=np.nan
# Out:
# ntransects, npoints:  288 126
# 34 -23 []
# 35 -22 []
# 36 -19 []
# 37 -20 []
# 38 -23 []
# 39 -24 []
# 40 -15 []
# 41 0 [1. 1.]
# 42 6 [1.         1.         0.83333333 0.7        0.56666667 0.43333333
#  0.3        0.16666667]
# 43 6 [1.         1.         0.83333333 0.7        0.56666667 0.43333333
#  0.3        0.16666667]
# 44 8 [1.         1.         0.875      0.76785714 0.66071429 0.55357143
#  0.44642857 0.33928571 0.23214286 0.125     ]
# 45 8 [1.         1.         0.875      0.76785714 0.66071429 0.55357143
#  0.44642857 0.33928571 0.23214286 0.125     ]
# 46 9 [1.         1.         0.88888889 0.79166667 0.69444444 0.59722222
#  0.5        0.40277778 0.30555556 0.20833333 0.11111111]
# 47 8 [1.         1.         0.875      0.76785714 0.66071429 0.55357143
#  0.44642857 0.33928571 0.23214286 0.125     ]
# 48 7 [1.         1.         0.85714286 0.73809524 0.61904762 0.5
#  0.38095238 0.26190476 0.14285714]
# 49 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 50 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 51 3 [1.         1.         0.66666667 0.5        0.33333333]
# 52 2 [1.         1.         0.66666667 0.33333333]
# 53 2 [1.         1.         0.66666667 0.33333333]
# 54 3 [1.         1.         0.66666667 0.5        0.33333333]
# 55 2 [1.         1.         0.66666667 0.33333333]
# 56 2 [1.         1.         0.66666667 0.33333333]
# 57 2 [1.         1.         0.66666667 0.33333333]
# 58 2 [1.         1.         0.66666667 0.33333333]
# 59 1 [1.  1.  0.5]
# 60 1 [1.  1.  0.5]
# 61 1 [1.  1.  0.5]
# 62 2 [1.         1.         0.66666667 0.33333333]
# 63 2 [1.         1.         0.66666667 0.33333333]
# 64 3 [1.         1.         0.66666667 0.5        0.33333333]
# 65 3 [1.         1.         0.66666667 0.5        0.33333333]
# 66 0 [1. 1.]
# 67 0 [1. 1.]
# 68 1 [1.  1.  0.5]
# 69 2 [1.         1.         0.66666667 0.33333333]
# 70 1 [1.  1.  0.5]
# 71 0 [1. 1.]
# 72 1 [1.  1.  0.5]
# 73 1 [1.  1.  0.5]
# 74 3 [1.         1.         0.66666667 0.5        0.33333333]
# 75 3 [1.         1.         0.66666667 0.5        0.33333333]
# 76 2 [1.         1.         0.66666667 0.33333333]
# 77 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 78 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 79 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 80 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 81 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 82 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 83 6 [1.         1.         0.83333333 0.7        0.56666667 0.43333333
#  0.3        0.16666667]
# 84 6 [1.         1.         0.83333333 0.7        0.56666667 0.43333333
#  0.3        0.16666667]
# 85 6 [1.         1.         0.83333333 0.7        0.56666667 0.43333333
#  0.3        0.16666667]
# 86 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 87 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 88 3 [1.         1.         0.66666667 0.5        0.33333333]
# 89 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 90 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 91 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 92 3 [1.         1.         0.66666667 0.5        0.33333333]
# 93 2 [1.         1.         0.66666667 0.33333333]
# 94 1 [1.  1.  0.5]
# 95 2 [1.         1.         0.66666667 0.33333333]
# 96 1 [1.  1.  0.5]
# 97 2 [1.         1.         0.66666667 0.33333333]
# 98 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 99 3 [1.         1.         0.66666667 0.5        0.33333333]
# 100 3 [1.         1.         0.66666667 0.5        0.33333333]
# 101 3 [1.         1.         0.66666667 0.5        0.33333333]
# 102 2 [1.         1.         0.66666667 0.33333333]
# 103 3 [1.         1.         0.66666667 0.5        0.33333333]
# 104 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 105 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 106 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 107 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 108 3 [1.         1.         0.66666667 0.5        0.33333333]
# 109 3 [1.         1.         0.66666667 0.5        0.33333333]
# 110 3 [1.         1.         0.66666667 0.5        0.33333333]
# 111 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 112 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 113 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 114 6 [1.         1.         0.83333333 0.7        0.56666667 0.43333333
#  0.3        0.16666667]
# 115 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 116 6 [1.         1.         0.83333333 0.7        0.56666667 0.43333333
#  0.3        0.16666667]
# 117 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 118 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 119 3 [1.         1.         0.66666667 0.5        0.33333333]
# 120 2 [1.         1.         0.66666667 0.33333333]
# 121 2 [1.         1.         0.66666667 0.33333333]
# 122 2 [1.         1.         0.66666667 0.33333333]
# 123 1 [1.  1.  0.5]
# 124 2 [1.         1.         0.66666667 0.33333333]
# 125 2 [1.         1.         0.66666667 0.33333333]
# 126 0 [1. 1.]
# 127 1 [1.  1.  0.5]
# 128 1 [1.  1.  0.5]
# 129 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 130 1 [1.  1.  0.5]
# 131 1 [1.  1.  0.5]
# 132 2 [1.         1.         0.66666667 0.33333333]
# 133 2 [1.         1.         0.66666667 0.33333333]
# 134 2 [1.         1.         0.66666667 0.33333333]
# 135 1 [1.  1.  0.5]
# 136 0 [1. 1.]
# 137 3 [1.         1.         0.66666667 0.5        0.33333333]
# 138 2 [1.         1.         0.66666667 0.33333333]
# 139 1 [1.  1.  0.5]
# 140 0 [1. 1.]
# 141 1 [1.  1.  0.5]
# 142 2 [1.         1.         0.66666667 0.33333333]
# 143 3 [1.         1.         0.66666667 0.5        0.33333333]
# 144 2 [1.         1.         0.66666667 0.33333333]
# 145 2 [1.         1.         0.66666667 0.33333333]
# 146 3 [1.         1.         0.66666667 0.5        0.33333333]
# 147 2 [1.         1.         0.66666667 0.33333333]
# 148 3 [1.         1.         0.66666667 0.5        0.33333333]
# 149 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 150 3 [1.         1.         0.66666667 0.5        0.33333333]
# 151 2 [1.         1.         0.66666667 0.33333333]
# 152 1 [1.  1.  0.5]
# 153 0 [1. 1.]
# 154 -2 []
# 155 -1 [1.]
# 156 1 [1.  1.  0.5]
# 157 2 [1.         1.         0.66666667 0.33333333]
# 158 3 [1.         1.         0.66666667 0.5        0.33333333]
# 159 2 [1.         1.         0.66666667 0.33333333]
# 160 2 [1.         1.         0.66666667 0.33333333]
# 161 2 [1.         1.         0.66666667 0.33333333]
# 162 2 [1.         1.         0.66666667 0.33333333]
# 163 1 [1.  1.  0.5]
# 164 0 [1. 1.]
# 165 1 [1.  1.  0.5]
# 166 1 [1.  1.  0.5]
# 167 1 [1.  1.  0.5]
# 168 2 [1.         1.         0.66666667 0.33333333]
# 169 1 [1.  1.  0.5]
# 170 1 [1.  1.  0.5]
# 171 2 [1.         1.         0.66666667 0.33333333]
# 172 2 [1.         1.         0.66666667 0.33333333]
# 173 1 [1.  1.  0.5]
# 174 0 [1. 1.]
# 175 2 [1.         1.         0.66666667 0.33333333]
# 176 2 [1.         1.         0.66666667 0.33333333]
# 177 2 [1.         1.         0.66666667 0.33333333]
# 178 2 [1.         1.         0.66666667 0.33333333]
# 179 2 [1.         1.         0.66666667 0.33333333]
# 180 3 [1.         1.         0.66666667 0.5        0.33333333]
# 181 3 [1.         1.         0.66666667 0.5        0.33333333]
# 182 2 [1.         1.         0.66666667 0.33333333]
# 183 2 [1.         1.         0.66666667 0.33333333]
# 184 2 [1.         1.         0.66666667 0.33333333]
# 185 2 [1.         1.         0.66666667 0.33333333]
# 186 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 187 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 188 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 189 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 190 3 [1.         1.         0.66666667 0.5        0.33333333]
# 191 2 [1.         1.         0.66666667 0.33333333]
# 192 2 [1.         1.         0.66666667 0.33333333]
# 193 1 [1.  1.  0.5]
# 194 2 [1.         1.         0.66666667 0.33333333]
# 195 2 [1.         1.         0.66666667 0.33333333]
# 196 0 [1. 1.]
# 197 0 [1. 1.]
# 198 1 [1.  1.  0.5]
# 199 2 [1.         1.         0.66666667 0.33333333]
# 200 3 [1.         1.         0.66666667 0.5        0.33333333]
# 201 3 [1.         1.         0.66666667 0.5        0.33333333]
# 202 2 [1.         1.         0.66666667 0.33333333]
# 203 2 [1.         1.         0.66666667 0.33333333]
# 204 3 [1.         1.         0.66666667 0.5        0.33333333]
# 205 2 [1.         1.         0.66666667 0.33333333]
# 206 2 [1.         1.         0.66666667 0.33333333]
# 207 3 [1.         1.         0.66666667 0.5        0.33333333]
# 208 3 [1.         1.         0.66666667 0.5        0.33333333]
# 209 3 [1.         1.         0.66666667 0.5        0.33333333]
# 210 3 [1.         1.         0.66666667 0.5        0.33333333]
# 211 3 [1.         1.         0.66666667 0.5        0.33333333]
# 212 2 [1.         1.         0.66666667 0.33333333]
# 213 2 [1.         1.         0.66666667 0.33333333]
# 214 3 [1.         1.         0.66666667 0.5        0.33333333]
# 215 3 [1.         1.         0.66666667 0.5        0.33333333]
# 216 3 [1.         1.         0.66666667 0.5        0.33333333]
# 217 3 [1.         1.         0.66666667 0.5        0.33333333]
# 218 3 [1.         1.         0.66666667 0.5        0.33333333]
# 219 2 [1.         1.         0.66666667 0.33333333]
# 220 3 [1.         1.         0.66666667 0.5        0.33333333]
# 221 8 [1.         1.         0.875      0.76785714 0.66071429 0.55357143
#  0.44642857 0.33928571 0.23214286 0.125     ]
# 222 8 [1.         1.         0.875      0.76785714 0.66071429 0.55357143
#  0.44642857 0.33928571 0.23214286 0.125     ]
# 223 8 [1.         1.         0.875      0.76785714 0.66071429 0.55357143
#  0.44642857 0.33928571 0.23214286 0.125     ]
# 224 1 [1.  1.  0.5]
# 225 2 [1.         1.         0.66666667 0.33333333]
# 226 0 [1. 1.]
# 227 1 [1.  1.  0.5]
# 228 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 229 6 [1.         1.         0.83333333 0.7        0.56666667 0.43333333
#  0.3        0.16666667]
# 230 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 231 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 232 6 [1.         1.         0.83333333 0.7        0.56666667 0.43333333
#  0.3        0.16666667]
# 233 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 234 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 235 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 236 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 237 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 238 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 239 6 [1.         1.         0.83333333 0.7        0.56666667 0.43333333
#  0.3        0.16666667]
# 240 8 [1.         1.         0.875      0.76785714 0.66071429 0.55357143
#  0.44642857 0.33928571 0.23214286 0.125     ]
# 241 7 [1.         1.         0.85714286 0.73809524 0.61904762 0.5
#  0.38095238 0.26190476 0.14285714]
# 242 6 [1.         1.         0.83333333 0.7        0.56666667 0.43333333
#  0.3        0.16666667]
# 243 6 [1.         1.         0.83333333 0.7        0.56666667 0.43333333
#  0.3        0.16666667]
# 244 7 [1.         1.         0.85714286 0.73809524 0.61904762 0.5
#  0.38095238 0.26190476 0.14285714]
# 245 8 [1.         1.         0.875      0.76785714 0.66071429 0.55357143
#  0.44642857 0.33928571 0.23214286 0.125     ]
# 246 8 [1.         1.         0.875      0.76785714 0.66071429 0.55357143
#  0.44642857 0.33928571 0.23214286 0.125     ]
# 247 8 [1.         1.         0.875      0.76785714 0.66071429 0.55357143
#  0.44642857 0.33928571 0.23214286 0.125     ]
# 248 9 [1.         1.         0.88888889 0.79166667 0.69444444 0.59722222
#  0.5        0.40277778 0.30555556 0.20833333 0.11111111]
# 249 7 [1.         1.         0.85714286 0.73809524 0.61904762 0.5
#  0.38095238 0.26190476 0.14285714]
# 250 7 [1.         1.         0.85714286 0.73809524 0.61904762 0.5
#  0.38095238 0.26190476 0.14285714]
# 251 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 252 -4 []
# 253 -26 []
# 254 -25 []
# 255 -25 []
# 256 -20 []
# 257 -9 []
# 258 -17 []
# 259 -16 []
# 260 -7 []
# 261 -3 []
# 262 -2 []
# 263 4 [1.         1.         0.75       0.58333333 0.41666667 0.25      ]
# 264 8 [1.         1.         0.875      0.76785714 0.66071429 0.55357143
#  0.44642857 0.33928571 0.23214286 0.125     ]
# 265 9 [1.         1.         0.88888889 0.79166667 0.69444444 0.59722222
#  0.5        0.40277778 0.30555556 0.20833333 0.11111111]
# 266 10 [1.         1.         0.9        0.81111111 0.72222222 0.63333333
#  0.54444444 0.45555556 0.36666667 0.27777778 0.18888889 0.1       ]
# 267 10 [1.         1.         0.9        0.81111111 0.72222222 0.63333333
#  0.54444444 0.45555556 0.36666667 0.27777778 0.18888889 0.1       ]
# 268 10 [1.         1.         0.9        0.81111111 0.72222222 0.63333333
#  0.54444444 0.45555556 0.36666667 0.27777778 0.18888889 0.1       ]
# 269 10 [1.         1.         0.9        0.81111111 0.72222222 0.63333333
#  0.54444444 0.45555556 0.36666667 0.27777778 0.18888889 0.1       ]
# 270 11 [1.         1.         0.90909091 0.82727273 0.74545455 0.66363636
#  0.58181818 0.5        0.41818182 0.33636364 0.25454545 0.17272727
#  0.09090909]
# 271 7 [1.         1.         0.85714286 0.73809524 0.61904762 0.5
#  0.38095238 0.26190476 0.14285714]
# 272 8 [1.         1.         0.875      0.76785714 0.66071429 0.55357143
#  0.44642857 0.33928571 0.23214286 0.125     ]
# 273 5 [1.   1.   0.8  0.65 0.5  0.35 0.2 ]
# 274 1 [1.  1.  0.5]
# 275 -1 [1.]
# 276 -2 []
# 277 -3 []
# 278 -9 []
# 279 -8 []
# 280 0 [1. 1.]

# %% [markdown]
# #### Look at some profiles to make sure this works

# %%
i=80
plt.plot(Zf1[:,i])
plt.plot(wghts[:,i])
plt.title('Example profile with weights')
plt.plot(Zf2j[:,i])
plt.plot(Zf2j[:,i]*(1.-wghts[:,i])+Zf1[:,i]*wghts[:,i],'-k')

# %%
plt.pcolormesh(wghts)
plt.title('Map of weights')
# Out:
# Text(0.5, 1.0, 'Map of weights')

# %%
# plots of the weighted values
fig = plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.pcolormesh(Zf1*wghts,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('SfM topo')
plt.subplot(1,2,2)
plt.pcolormesh(Zf2j*(1.-wghts),vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Jetyak bathy')
# Out:
# Text(0.5, 1.0, 'Jetyak bathy')

# %%
# I don't understand why the NaN regions end up with zeros
Zf2 = np.nansum(np.stack( (wghts*Zf1,(1.-wghts)*Zf2j), axis=-1), axis=2 )
# Here is my non-pythonis workaround
nanregion = (np.nanmax(np.stack( (~np.isnan(Zf1), ~np.isnan(Zf2j)), axis=-1), axis=2 )).astype(float)
nanregion[nanregion==0.]=np.NaN
plt.pcolormesh(nanregion)
nanregion
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
Zf2=Zf2*nanregion
# then smooth it in an attempt to fill the holes
kernel = Gaussian2DKernel(x_stddev=.25)
# astropy's convolution replaces the NaN pixels with a kernel-weighted
# interpolation from their neighbors

print('Smoothing with kernel size',np.shape(kernel))
Zf2_s = convolve(Zf2, kernel, boundary='extend')

fig = plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.pcolormesh(Xf,Yf,Zf2,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Zf2 - SfM and Jetyak data on fine grid')
plt.colorbar();
plt.subplot(1,2,2)
plt.pcolormesh(Xf,Yf,Zf2_s,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Zf2_s - Smoothed SfM and Jetyak data on fine grid')
plt.colorbar();
# Out:
# Smoothing with kernel size (3, 3)

# %%
fig = plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.pcolormesh(Xf,Yf,Zf2,vmin=-8,vmax=10,cmap=plt.cm.terrain)
for i in np.array([50,75,100,125,150,200,250]):
    plt.plot(Xf[:,i],Yf[:,i],'-')
plt.title('Zf2 - SfM and Jetyak data on fine grid')
plt.colorbar()
plt.axis('equal');
plt.subplot(1,2,2)
for i in np.array([50,75,100,125,150,200,250]):
    plt.plot(Xf[:,i],Zf1[:,i],'-')
plt.title('Profiles')
# Out:
# Text(0.5, 1.0, 'Profiles')

# %% [markdown]
# ### Write the fine grid as a .tiff file

# %% [raw]
# # This has not been implemented yet...the Affine tranformation needs to be fixed.
# # But it will go something like this:
#
# import rasterio # rasterio and OGR don't mix...see rasterio docs
# from rasterio import Affine
#
# print("xsize = ",np.shape(Xf),(Xf[0][0]),Xf[0][-1],Xf[-1][0])
# CRS = {'init': 'epsg:6348'}
#
# # According to https://www.perrygeo.com/python-affine-transforms.html, the elements of the affine matrix are:
# #
# # a = width of a pixel
# # b = row rotation (typically zero)
# # c = x-coordinate of the upper-left corner of the upper-left pixel
# # d = column rotation (typically zero)
# # e = height of a pixel (typically negative)
# # f = y-coordinate of the of the upper-left corner of the upper-left pixel
# # Refer to the last file opened to help define the output coord. ref. system and save as a "profile"
# # Force the file type and array to be dtype="float32"
#
# Transform = Affine(5., 0.00, Xf[0], 0.00, -5., Yf[0])
# profile = {'driver': 'GTiff', 'height': ysize, 'width': xsize, 'count': 1,\
#            'dtype': 'float32', 'crs':CRS, 'transform': Transform }
# print(profile)
#
# # write the tiff files
# with rasterio.open('zmean.tif', 'w',nodata=np.nan, **profile) as dst:
#     dst.write(zmean.astype("float32"), indexes=1)
#     dst.close()

# %% [markdown]
# ### Interpolate the smoothed lidar data onto the fine grid: -> `Zf2l`...no holes.

# %%
# %%time
# Make the fine grid with lidar data
xp, yp = np.meshgrid(xlidar,ylidar)
xpyp = np.array((np.ravel(xp),np.ravel(yp))).T
zp = np.ravel(zlidars)
print('xp ',np.shape(xp),'yp: ' ,np.shape(yp),'xpyp: ',np.shape(xpyp),'zp: :',np.shape(zp))
print('Xf ',np.shape(Xf),'Yf: ' ,np.shape(Yf),'grid points: ',np.shape(np.array((np.ravel(Xf), np.ravel(Yf))).T))

# interpolate data on to fine grid
Zf2l = interpolate.griddata( xpyp, zp, np.array((np.ravel(Xf), np.ravel(Yf))).T, method='linear', fill_value=np.NaN, rescale=False)
Zf2l = np.reshape(Zf2l,np.shape(Xf))
# Out:
# xp  (1673, 2450) yp:  (1673, 2450) xpyp:  (4098850, 2) zp: : (4098850,)
# Xf  (126, 288) Yf:  (126, 288) grid points:  (36288, 2)
# Wall time: 1min 30s

# %%
plt.pcolormesh(Xf,Yf,Zf2l,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Zf2l - Lidar data on fine grid')
plt.colorbar();

# %% [markdown]
# ### Mask out the regions in `Zf2l` where merged SfM and Jetyak (`Zf2_s`) has data: -> `Zf3`...has gaps.

# %%
Zf_has_sfm_jet = np.array(~np.isnan(Zf2_s))
Zf3 = Zf2l.copy()
Zf3[Zf_has_sfm_jet]=np.NaN

# %%
plt.pcolormesh(Xf,Yf,Zf3,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Zf3 - Lidar data with gaps to be filled with SfM and Jetyak')
plt.colorbar();

# %% [markdown]
# ### Make a complete grid by `nansum`ing the two grids:-> `Zf4`
#
# This grid is complete, but there can be a sharp discontinuity between the two datasets. See next step for smoothing.

# %%
Zstack = np.stack((Zf2_s,Zf3))
Zf4 = np.nanmean(Zstack, 0)

fig = plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.pcolormesh(Xf,Yf,Zf4,vmin=-8,vmax=10,cmap=plt.cm.terrain)
for i in np.array([50,75,100,125,150,200,250]):
    plt.plot(Xf[:,i],Yf[:,i],'-')
plt.title('Zf4 - Rough but complete fine grid')
plt.colorbar()
plt.axis('equal');
plt.subplot(1,2,2)
for i in np.array([50,75,100,125,150,200,250]):
    plt.plot(Xf[:,i],Zf4[:,i],'-')
plt.title('Profiles with notches near -1 m')
# Out:
# Text(0.5, 1.0, 'Profiles with notches near -1 m')

# %% [markdown]
# ### For now, assign final find grid `Zf` to `Zf4`
# * There are issues in the NW region, but they may not matter much

# %%
Zf = Zf4.copy()

# %%
i = 150
plt.plot(Xf[:,i],Zf1[:,i],'-k',label='SfM')
plt.plot(Xf[:,i],Zf2_s[:,i],'-b',label='SfM + Jetkak')
plt.plot(Xf[:,i],Zf3[:,i],'.c',label='valid lidar')
plt.plot(Xf[:,i],Zf4[:,i],'--r',label='merged')
#plt.xlim(idx[i]-20,idx[i]+20)
plt.title('Example profile at '+str(i))
plt.legend();

# %% [markdown]
# ### Interpolate fine grid onto the medium grid: -> `Zm1` with lots of missing data

# %%
# %%time
xpyp = np.array((np.ravel(Xf),np.ravel(Yf))).T
zp = np.ravel(Zf)
print('xp ',np.shape(xp),'yp: ' ,np.shape(yp),'xpyp: ',np.shape(xpyp),'zp: :',np.shape(zp))
print('Xm ',np.shape(Xm),'Ym: ' ,np.shape(Ym),'grid points: ',np.shape(np.array((np.ravel(Xm), np.ravel(Ym))).T))

# interpolate data on to fine grid
Zm1 = interpolate.griddata( xpyp, zp, np.array((np.ravel(Xm), np.ravel(Ym))).T, method='linear', fill_value=np.NaN, rescale=False)
Zm1 = np.reshape(Zm1,np.shape(Xm))

plt.pcolormesh(Xm,Ym,Zm1,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Zm1 - Fine grid as data on medium grid')
plt.colorbar();
# Out:
# xp  (1673, 2450) yp:  (1673, 2450) xpyp:  (36288, 2) zp: : (36288,)
# Xm  (64, 190) Ym:  (64, 190) grid points:  (12160, 2)
# Wall time: 683 ms

# %% [markdown]
# ### Interpolate the lidar data on to the medium grid: -> `Zm2` with a little missing data at outer edge

# %%
# %%time
xp, yp = np.meshgrid(xlidar,ylidar)
xpyp = np.array((np.ravel(xp),np.ravel(yp))).T
zp = np.ravel(zlidars)
print('xp ',np.shape(xp),'yp: ' ,np.shape(yp),'xpyp: ',np.shape(xpyp),'zp: :',np.shape(zp))
print('Xm ',np.shape(Xm),'Ym: ' ,np.shape(Ym),'grid points: ',np.shape(np.array((np.ravel(Xm), np.ravel(Ym))).T))

# interpolate data on to medium grid
Zm2 = interpolate.griddata( xpyp, zp, np.array((np.ravel(Xm), np.ravel(Ym))).T, method='linear', fill_value=np.NaN, rescale=False)
Zm2 = np.reshape(Zm2,np.shape(Xm))

plt.pcolormesh(Xm,Ym,Zm2,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Zm2 - Lidar data on medium grid')
plt.colorbar();
# Out:
# xp  (1673, 2450) yp:  (1673, 2450) xpyp:  (4098850, 2) zp: : (4098850,)
# Xm  (64, 190) Ym:  (64, 190) grid points:  (12160, 2)
# Wall time: 1min 29s

# %% [markdown]
# ### Remove 4 cells from outer edge of the lidar data. Weird stuff happens there.

# %%
# Find the indices for the end of each transect
idx=[]
npoints, ntransects= np.shape(Zm2)
print('ntransects, npoints: ',ntransects,npoints)
for i in range(ntransects):
    j=np.argwhere(np.isnan(Zm2[:,i]))
    if(j.any()):
        idx = np.append(idx,j[-1])
    else:
        idx = np.append(idx,-1)

# NaN from edge minus noff to end
noff = 4 #  grid cells = 70 m
for i in range(ntransects):
    if idx[i]>noff:
        k = int(idx[i])-noff
        Zm2[k:,i]=np.NaN

plt.pcolormesh(Xm,Ym,Zm2,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Zm2 - Lidar data on medium grid')
plt.colorbar();
# Out:
# ntransects, npoints:  190 64

# %% [markdown]
# ### Interpolate the clipped, smoothed, filled 10-m data on to the medium grid: -> `Zm3` with full coverage

# %%
# %%time
xp, yp = np.meshgrid(x10c,y10c)
xpyp = np.array((np.ravel(xp),np.ravel(yp))).T
zp = np.ravel(z10csf)
print('xp ',np.shape(xp),'yp: ' ,np.shape(yp),'xpyp: ',np.shape(xpyp),'zp: :',np.shape(zp))
print('Xm ',np.shape(Xm),'Ym: ' ,np.shape(Ym),'grid points: ',np.shape(np.array((np.ravel(Xm), np.ravel(Ym))).T))
Zm3 = interpolate.griddata( xpyp, zp, np.array((np.ravel(Xm), np.ravel(Ym))).T, method='nearest', fill_value=np.NaN, rescale=False)
Zm3 = np.reshape(Zm3,np.shape(Xm))
# Out:
# xp  (3852, 4874) yp:  (3852, 4874) xpyp:  (18774648, 2) zp: : (18774648,)
# Xm  (64, 190) Ym:  (64, 190) grid points:  (12160, 2)
# Wall time: 3min

# %%
plt.pcolormesh(Xm,Ym,Zm3,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Zm3 - 10-m data on medium grid')
plt.colorbar();

# %% [markdown]
# ### Remove lidar coverage from 10-m grid version of medium grid: -> `Zm4`

# %%
Zm_has_lidar = np.array(~np.isnan(Zm2))
Zm4 = Zm3.copy()
Zm4[Zm_has_lidar]=np.NaN

plt.pcolormesh(Xm,Ym,Zm4,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Zm4 - 10-m data on medium grid, lidar removed')
plt.colorbar();

# %% [markdown]
# ### Remove SfM and Jetyak coverage from lidar version of medium grid: -> `Zm5`

# %%
Zm_has_sfm = np.array(~np.isnan(Zm1))
Zm5 = Zm2.copy()
Zm5[Zm_has_sfm]=np.NaN

plt.pcolormesh(Xm,Ym,Zm5,vmin=-8,vmax=10,cmap=plt.cm.terrain)
plt.title('Zm5 - lidar data on medium grid, sfm removed')
plt.colorbar();

# %% [markdown]
# ### Complete medium grid by combining `Zm1`, `Zm4`, and `Zm5` -> `Zm`

# %%
Zmstack = np.stack((Zm1,Zm4,Zm5))
Zm = np.nanmean(Zmstack, 0)

# %%
# plot
fig = plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
plt.pcolormesh(Xm,Ym,Zm,vmin=-20,vmax=10,cmap=plt.cm.terrain)
for i in np.array([50,75,100,112,125,150]):
    plt.plot(Xm[:,i],Ym[:,i],'-')

plt.title('Zm - Final medium grid')
plt.colorbar()
plt.axis('equal');
plt.subplot(1,2,2)
for i in np.array([50,75,100,112,125]):
    plt.plot(Xm[:,i],Zm1[:,i],'-k')
    plt.plot(Xm[:,i],Zm5[:,i],'-b')
    plt.plot(Xm[:,i],Zm4[:,i],'.c')
    plt.plot(Xm[:,i],Zm[:,i],'--r')

# one last transect to get the legend
i=150
plt.plot(Xm[:,i],Zm1[:,i],'-k',label='SfM')
plt.plot(Xm[:,i],Zm5[:,i],'-b',label='lidar')
plt.plot(Xm[:,i],Zm4[:,i],'.c',label='10m')
plt.plot(Xm[:,i],Zm[:,i],'--r',label='merged')
plt.title('Representative profiles')
plt.legend();

# %% [markdown]
# ### Use points in medium grid and 10-m data to interpolate the coarse grid: -> `Zc1` with lots of missing data

# %%
# %%time
# Interpolate the medium grid data onto the coarse grid
xpyp = np.array((np.ravel(Xm),np.ravel(Ym))).T
zp = np.ravel(Zm)
print('xp ',np.shape(xp),'yp: ' ,np.shape(yp),'xpyp: ',np.shape(xpyp),'zp: :',np.shape(zp))
print('Xc ',np.shape(Xc),'Yc: ' ,np.shape(Yc),'grid points: ',np.shape(np.array((np.ravel(Xc), np.ravel(Yc))).T))

# interpolate medium grid data on to the coarse grid
Zc1 = interpolate.griddata( xpyp, zp, np.array((np.ravel(Xc), np.ravel(Yc))).T, method='linear', fill_value=np.NaN, rescale=False)
Zc1 = np.reshape(Zc1,np.shape(Xc))

plt.pcolormesh(Xc,Yc,Zc1,vmin=-20,vmax=10,cmap=plt.cm.terrain)
plt.title('Zc1 - Medium grid as data on coarse grid')
plt.colorbar();
# Out:
# xp  (3852, 4874) yp:  (3852, 4874) xpyp:  (12160, 2) zp: : (12160,)
# Xc  (68, 192) Yc:  (68, 192) grid points:  (13056, 2)
# Wall time: 251 ms

# %% [markdown]
# ### Interpolate the clipped 10-m data on to the coarse grid: -> `Zc2` with no data gaps

# %%
# %%time
xp, yp = np.meshgrid(x10c,y10c)
xpyp = np.array((np.ravel(xp),np.ravel(yp))).T
zp = np.ravel(z10csf)
print('xp ',np.shape(xp),'yp: ' ,np.shape(yp),'xpyp: ',np.shape(xpyp),'zp: :',np.shape(zp))
print('Xc ',np.shape(Xc),'Yc: ' ,np.shape(Yc),'grid points: ',np.shape(np.array((np.ravel(Xc), np.ravel(Yc))).T))

Zc2 = interpolate.griddata( xpyp, zp, np.array((np.ravel(Xc), np.ravel(Yc))).T, method='nearest', fill_value=np.NaN, rescale=False)
Zc2 = np.reshape(Zc2,np.shape(Xc))
# Out:
# xp  (3852, 4874) yp:  (3852, 4874) xpyp:  (18774648, 2) zp: : (18774648,)
# Xc  (68, 192) Yc:  (68, 192) grid points:  (13056, 2)
# Wall time: 2min 59s

# %%
plt.pcolormesh(Xc,Yc,Zc2,vmin=-20,vmax=10,cmap=plt.cm.terrain)
plt.title('Zc2 - 10-m data on coarse grid')
plt.colorbar();

# %% [markdown]
# ### Remove medium grid coverage from 10-m grid version of coarse grid: -> `Zc3`

# %%
Zc_has_med = np.array(~np.isnan(Zc1))
Zc3 = Zc2.copy()
Zc3[Zc_has_med]=np.NaN

plt.pcolormesh(Xc,Yc,Zc3,vmin=-20,vmax=10,cmap=plt.cm.terrain)
plt.title('Zc3 - 10-m data on coarse grid, medium grid removed')
plt.colorbar();

# %% [markdown]
# ### Complete coarse grid by combining `Zc1` + `Zc2` -> `Zc`

# %%
Zcstack = np.stack((Zc1,Zc3))
Zc = np.nanmean(Zcstack, 0)

# %%
# plot
fig = plt.figure(figsize=(18,6))
plt.subplot(1,2,1)
plt.pcolormesh(Xc,Yc,Zc,vmin=-20,vmax=10,cmap=plt.cm.terrain)
for i in np.array([50,75,100,112,125,150]):
    plt.plot(Xc[:,i],Yc[:,i],'-')

plt.title('Zc - Final coarse grid')
plt.colorbar()
plt.axis('equal');
plt.subplot(1,2,2)
for i in np.array([50,75,100,112,125]):
    plt.plot(Xc[:,i],Zc[:,i],'-')

# one last transect to get the legend
i=150
plt.plot(Xc[:,i],Zc[:,i],'-',label='merged')
plt.title('Representative profiles')
plt.legend();

# %% [markdown]
# ### Calculate lat/lon coordinates for all three grids

# %%
from pyproj import Proj, transform

outProj = Proj(init='epsg:4326') #WGS84
inProj = Proj(init='epsg:26919') #NAD83 UTM Zone 19N

# Random coordinates with VDatum conversion to check
inx_check=374842.83098
iny_check=4624229.06884

outlon_check=-70.505576
outlat_check= 41.760044

outlon,outlat=transform(inProj,outProj,inx_check,iny_check)

print("Converted Lon / Lat   :  ",outlon,outlat)
print("Reference             :  ",outlon_check, outlat_check)
print("latitude difference = ", (outlat-outlat_check)*111111," meters.")
print("This discrepency is probably due to EPSG:4326 != the CRS used in VDATUM")

outlon, outlat = transform(inProj, outProj, np.ravel(Xf), np.ravel(Yf) )
Latf = np.reshape(outlat, np.shape(Yf))
Lonf = np.reshape(outlon, np.shape(Xf))

outlon, outlat = transform(inProj, outProj, np.ravel(Xm), np.ravel(Ym) )
Latm = np.reshape(outlat, np.shape(Ym))
Lonm = np.reshape(outlon, np.shape(Xm))

outlon, outlat = transform(inProj, outProj, np.ravel(Xc), np.ravel(Yc) )
Latc = np.reshape(outlat, np.shape(Yc))
Lonc = np.reshape(outlon, np.shape(Xc))
# Out:
# Converted Lon / Lat   :   -70.5055751610997 41.76003504123531
# Reference             :   -70.505576 41.760044
# latitude difference =  -0.9954173032834817  meters.
# This discrepency is probably due to EPSG:4326 != the CRS used in VDATUM

# %% [markdown]
# ### Write grids in as `.mat` files

# %%
scipy.io.savemat(ddir+'FG5.mat', mdict={'Latf':Latf, 'Lonf':Lonf, 'Xf':Xf,'Yf':Yf,'Zf': Zf})
scipy.io.savemat(ddir+'MG5.mat', mdict={'Latm':Latm, 'Lonm':Lonm, 'Xm':Xm,'Ym':Ym,'Zm': Zm})
scipy.io.savemat(ddir+'CG5.mat', mdict={'Latc':Latc, 'Lonc':Lonc, 'Xc':Xc,'Yc':Yc,'Zc': Zc})

# %% [markdown]
# ### One more step in Matlab:
#
# * Modify and use `CCBay_create_roms_xygrid.m` to convert from `.mat` to `netcdf`
